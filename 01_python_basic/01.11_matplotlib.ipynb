# %% [markdown]
# # Plotting data with matplotlib
#
# Plotting of data in python is handled by an external Python module called *matplotlib* (there are more).
# It is a large library and has a venerable history (first released in 2003) and so we couldn't hope to cover all its functionality in this course. To see the wide range of possibilities you have with matplotlib see its [example gallery](http://matplotlib.org/gallery.html).
#
# Here we will cover the basic uses. While working through these examples you will likely find it very useful to refer to the [matplotlib documentation](http://matplotlib.org/api/pyplot_api.html).

# %% [markdown]
# First we import pandas and numpy in the same way as we did previously.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Some matplotlib functionality is provided directly through pandas (such as the `plot()` method as we will see) but for much of it you need to import the matplotlib interface itself.
#
# The most common interface to matplotlib is its `pyplot` module which provides a way to affect the current state of matplotlib directly. [By convention](http://matplotlib.org/faq/usage_faq.html#coding-styles) this is imported as `plt`.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Once we have imported matplotlib we can start calling its functions. Any functions called on the `plt` object will affect all of matplotlib from that point on in the script.

# %% [markdown]
# ## Plot

# %%
plt.plot()
# Out:
# []

# %% [markdown]
# By default, the plot() function draws a line from point to point.
# The function takes parameters for specifying points in the diagram.
# - Parameter 1 is an array containing the points on the x-axis.
# - Parameter 2 is an array containing the points on the y-axis.

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.plot(ypoints)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

plt.plot(ypoints)

# %% [markdown]
# ### markers

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, marker='o') #, ms = 20
plt.show()

# %% [markdown]
# more on markers in https://www.w3schools.com/python/matplotlib_markers.asp

# %% [markdown]
# ### lines

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, linestyle = 'dashed') #
plt.show()

# %% [markdown]
# linestyle can be written as ls
#
# dotted can be written as :
#
# dashed can be written as --

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, linestyle = 'dashed', color='red', linewidth = '10.5')
plt.show()

# %% [markdown]
# ### marker|line|color

# %% [markdown]
# You can use also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
# marker|line|color
# Example
#
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o--r')
plt.show()

# %% [markdown]
# ### Labels

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o--r')
plt.xlabel("x label")
plt.ylabel("y label")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o--r')
plt.xlabel("x label")
plt.ylabel("y label")
plt.title('title', size=14, loc = 'left')
plt.show()

# %% [markdown]
# ### grid

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, 'o--r')

plt.grid()
# plt.grid(axis = 'x')


plt.xlabel("x label")
plt.ylabel("y label")
plt.title('title', size=14, loc = 'left')
plt.show()

# %%
plt.figure(figsize=(12,6), dpi=300)
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, 'o--r')
plt.grid()
plt.xlabel("x label")
plt.ylabel("y label")
plt.title('title', size=14, loc = 'left')
plt.show()

# %% [markdown]
# ### scale

# %%
X = np.linspace(0, 10, 100, endpoint=True)

plt.plot(X, np.exp(-X), label='cos(x)')
plt.xlabel('X')
plt.show()

# %%
X = np.linspace(0, 10, 100, endpoint=True)

plt.plot(X, np.exp(-X), label='cos(x)')
plt.xlabel('X')
plt.yscale('log')
plt.show()

# %% [markdown]
# ### legend

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)

plt.plot(X, np.cos(X), label='cos(x)')
plt.plot(X, np.sin(X), label='sin(x)')
plt.legend(title = "functions:")
plt.xlabel('X')
plt.show()

# %% [markdown]
# ### Setting limits
#
# Current limits of the figure are a bit too tight and we want to make some space in order to clearly see all data points.

# %%
plt.plot(X, np.cos(X), label='cos(x)', color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, np.sin(X), label='sin(x)', color="red", linewidth=2.5, linestyle="-")
plt.legend()
#plt.legend(loc='upper left')

plt.xlabel('X')
plt.ylim(-1.2, 1.2)
plt.show()

# %% [markdown]
# ### Setting ticks
#
# Current ticks are not ideal because they do not show the interesting values ($\pm\pi$,$\pm\frac{\pi}{2}$) for sine and cosine. We’ll change them such that they show only these values.

# %%
plt.plot(X, np.cos(X), label='cos(x)', color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, np.sin(X), label='sin(x)', color="red", linewidth=2.5, linestyle="-")
plt.legend()
plt.xlabel('X')
plt.ylim(-1.2, 1.2)

### New code
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])
### End of new code

plt.show()

# %% [markdown]
# ### Setting tick labels
#
# Ticks are now properly placed but their label is not very explicit. We could guess that 3.142 is $\pi$ but it would be better to make it explicit. When we set tick values, we can also provide a corresponding label in the second argument list. Note that we’ll use LaTeX to allow for nice rendering of the label.

# %%
plt.plot(X, np.cos(X), label='cos(x)', color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, np.sin(X), label='sin(x)', color="red", linewidth=2.5, linestyle="-")
plt.legend()
plt.xlabel('X')
plt.ylim(-1.2, 1.2)

### New code
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
           [r'$-1$', r'$0$', r'$+1$'])
### End of new code

plt.show()

# %% [markdown]
# ### Annotate some points
#
# Let’s annotate some interesting points using the annotate command. We chose the $\frac{2}{3}\pi$ value and we want to annotate both the sine and the cosine. We’ll first draw a marker on the curve as well as a straight dotted line. Then, we’ll use the annotate command to display some text with an arrow.

# %%
plt.plot(X, np.cos(X), label='cos(x)', color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, np.sin(X), label='sin(x)', color="red", linewidth=2.5, linestyle="-")
plt.xlabel('X')
plt.ylim(-1.2, 1.2)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
           [r'$-1$', r'$0$', r'$+1$'])


plt.legend(loc='upper left')

### New code
t = np.pi / 2

plt.annotate(r'$sin(\frac{\pi}{2})=1$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+90, +50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))


plt.show()

# %% [markdown]
# # Saving plot to a file
#
# You can take any plot you've created within Jupyter and save it to a file on disk using the `plt.savefig()` function. You give the function the name of the file to create and it will use whatever format is specified by the name.

# %%
plt.plot(X, np.cos(X), label='cos(x)', color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, np.sin(X), label='sin(x)', color="red", linewidth=2.5, linestyle="-")
plt.legend()
plt.xlabel('X')
plt.ylim(-1.2, 1.2)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
           [r'$-1$', r'$0$', r'$+1$'])

plt.savefig('my_fig.png', dpi=300)
plt.show()

# %% [markdown]
# # Subplots

# %%
x = np.linspace(-10, 10, 100)

plt.figure(figsize=(10,8))
for i in [1, 2, 3, 4, 5, 6]:
    plt.subplot(3,2,i)
    plt.plot(x,x**i, label=f'$x^{i}$')
    plt.legend()
    #plt.xlabel('x')

# %% [markdown]
# ax

# %%
fig, ax = plt.subplots()
x = np.linspace(-10, 10, 100)
ax.plot(x, x**2)
ax.grid()
ax.set_xlabel('X')
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(10,8))
ax[0,0].plot(x,x)
ax[0,1].plot(x,x**2)
ax[1,0].plot(x,x**3)
ax[1,1].plot(x,x**4)
ax[2,0].plot(x,x**5)
ax[2,1].plot(x,x**6, label='x^6')
ax[2,1].legend()
fig.suptitle('x^n')
# Out:
# Text(0.5, 0.98, 'x^n')

# %% [markdown]
# # Scatter plots

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.plot(x, y, 'o')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
df = pd.read_csv(
    'city_pop.csv',
    skiprows=5,
    sep=';',
    na_values='-1'
)
df
# Out:
#    year  London  Paris   Rome
# 0  2001   7.322  2.148  2.547
# 1  2006   7.652    NaN  2.627
# 2  2008     NaN  2.211    NaN
# 3  2009     NaN  2.234  2.734
# 4  2011   8.174    NaN    NaN
# 5  2012     NaN  2.244  2.627
# 6  2015   8.615    NaN    NaN

# %%
df.columns
# Out:
# Index(['year', 'London', 'Paris', 'Rome'], dtype='object')

# %%
for column in df.columns[1:]:
    plt.scatter(df['year'].values, df[column].values, label=column)
plt.legend()
plt.grid()
plt.xlabel('year', size=14)
plt.ylabel('population', size=14)
plt.show()

# %% [markdown]
# ## real life research example

# %%
xmin, xmax = 1.5, -12.5
ymin, ymax = 1, -6
Vdmax=-12

sample='D3'

df=pd.read_csv(f'data/NEWOFET_Id-Vd_D3_txt.csv', skiprows=12)
df
# Out:
#       Vdrain        Idrain         Igate          rout  Vgate  Vsource  \
# 0        1.0  6.563860e-10  2.482000e-12  1.135622e+09      0        0
# 1        0.8  4.802710e-10  1.038000e-12  1.235185e+09      0        0
# 2        0.6  3.325480e-10  6.110000e-13  1.455668e+09      0        0
# 3        0.4  2.054830e-10  8.140000e-13  1.686931e+09      0        0
# 4        0.2  9.543100e-11  1.133000e-12  1.929217e+09      0        0
# ...      ...           ...           ...           ...    ...      ...
# 1267     0.2  8.574190e-07 -9.146000e-12  2.289096e+05    -15        0
# 1268     0.4  1.747940e-06  1.875000e-12  2.186233e+05    -15        0
# 1269     0.6  2.687050e-06  1.024000e-12  2.095074e+05    -15        0
# 1270     0.8  3.657180e-06 -7.712000e-12  2.006370e+05    -15        0
# 1271     1.0  4.680700e-06 -9.189000e-12  1.954041e+05    -15        0
#
#        IdrainPerWg
# 0     6.563860e-11
# 1     4.802710e-11
# 2     3.325480e-11
# 3     2.054830e-11
# ...

# %%
#paper

for gate in df.Vgate.unique()[1:5]:
    dn=df.query('Vgate=={}'.format(gate))
    plt.plot(dn.query('Vdrain>=@Vdmax').Vdrain, (dn.query('Vdrain>=@Vdmax').Idrain)*1E6, '-', label=r'$\rm{V_{gs}=}$'+'{}V'.format(gate).replace('-', '\N{MINUS SIGN}'))
    #plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.grid()
plt.legend(fontsize=14, bbox_to_anchor=(0.99, 0.80), loc='upper right')
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
#plt.ylim(-4.5E-5, .1E-5)
plt.xlabel(r'$\rm{V_{ds}}$ [V]', size=18)
plt.ylabel(r'$\rm{I_{ds}}$ [$\mu$A]', size=18)
#plt.title('OPT_'+sample+' - OUTPUT CHARACTERISTICS')
#plt.savefig('./fig/charact_a.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0, 0.5, '$\\rm{I_{ds}}$ [$\\mu$A]')

# %%
df=pd.read_csv(f'data/NEWOFET_Id-Vg_all_D3_txt.csv', skiprows=12)

# %%
for drain in df.Vdrain.unique():
    dn=df.query('Vdrain=={}'.format(drain))
    plt.plot(dn.query('-9<=Vgate<=4').Vgate, abs(dn.query('-9<=Vgate<=4').Idrain*1E6), label=r'$\rm{V_{ds}} = $'+'{}V'.format(drain).replace('-', '\N{MINUS SIGN}'))
plt.grid()
plt.legend(fontsize=14)
plt.xlim(-10, 5)
plt.xlabel(r'$\rm{V_{gs}}$ [V]', size=18)
plt.ylabel(r'|$\rm{I_{ds}}$| [$\mu$A]', size=18)
#plt.title('OPT_'+sample+' - TRANSFER CHARACTERISTICS')
#plt.savefig('./fig/charact_b.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0, 0.5, '|$\\rm{I_{ds}}$| [$\\mu$A]')

# %%
for drain in df.Vdrain.unique():
    dn=df.query('Vdrain=={}'.format(drain))
    plt.plot(dn.query('-9<=Vgate<=4').Vgate, abs(dn.query('-9<=Vgate<=4').Idrain*1E6), label=r'$\rm{V_{ds}} = $'+'{}V'.format(drain).replace('-', '\N{MINUS SIGN}'))
plt.grid()
plt.legend(fontsize=14)
plt.xlim(-10, 5)
plt.xlabel(r'$\rm{V_{gs}}$ [V]', size=18)
plt.ylabel(r'|$\rm{I_{ds}}$| [$\mu$A]', size=18)
plt.yscale('log')

# %%
for drain in df.Vdrain.unique():
    dn=df.query('Vdrain=={}'.format(drain))
    plt.plot(dn.query('-9<=Vgate<=4').Vgate, abs(dn.query('-9<=Vgate<=4').Igate*1E6), label=r'$\rm{V_{ds}} = $'+'{}V'.format(drain).replace('-', '\N{MINUS SIGN}'))
plt.grid()
plt.legend(fontsize=14)
#plt.ylim(0, 0.5)
plt.ylim(1E-10, 1)
plt.xlim(-10, 5)
plt.xlabel(r'$\rm{V_{gs}}$ [V]', size=18)
plt.ylabel(r'|$\rm{I_{gs}}$| [$\mu$A]', size=18)
plt.yscale('log')
#plt.title('OPT_'+sample+' - TRANSFER CHARACTERISTICS')
#plt.savefig('./fig/charact_d.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # Bar plots

# %% [markdown]
# The ```bar()``` function takes arguments that describes the layout of the bars.
#
# The categories and their values represented by the first and second argument as arrays.

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y) #color="red"
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
y1 = np.array([3, 8, 1, 10])+2

plt.bar(x,y, width = 0.1) #color="red"
plt.bar(x,y1, width = 0.1) #color="red"
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# ## stacked bar

# %% [markdown]
# Stacked bar charts represent the values which take different groups within other groups. For instance, consider that people living in five different cities (e.g., the groups, named 'G1', 'G2', 'G3', 'G4' and 'G5') answered Yes or No to one question and the results (the count of Yes and No for each city) were stored into values1 and values2 variables.
#
# This data can be represented in Python with the bar function from matplotlib making use of the bottom argument, which represents the Y coordinates used to draw the bottom of the bars, so you can stack several bars.

# %%
# Data
groups = ['G1', 'G2', 'G3', 'G4', 'G5']
values1 = [12, 19, 14, 27, 16]
values2 = [21, 30, 15, 17, 20]

# Stacked bar chart
plt.bar(groups, values1, label = "Yes")
plt.bar(groups, values2, bottom = values1, label = "No")

plt.legend()
plt.ylabel('Number of answers')

# plt.show()
# Out:
# Text(0, 0.5, 'Number of answers')

# %% [markdown]
# # Pie Charts

# %% [markdown]
# With Pyplot, you can use the pie() function to draw pie charts:

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# The size of each wedge is determined by comparing the value with all the other values, by using this formula:
#
# The value divided by the sum of all values: x/sum(x)

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)

plt.legend()
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
#Pull the "Apples" wedge 0.2 from the center of the pie:

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# # Histogram
#
# It is a graph showing the number of observations within each given interval.

# %% [markdown]
# In Matplotlib, we use the hist() function to create histograms.
#
# The ```hist()``` function will use an array of numbers to create a histogram, the array is sent into the function as an argument.

# %% [markdown]
# Let's import some data

# %%
from sklearn import datasets
# import some data to play with
iris = datasets.load_iris()
df=pd.DataFrame(iris.data, columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid'])
df['f_class']=iris.target

# %% [markdown]
# This data sets consists of 3 different types of irises’ (Setosa, Versicolour, and Virginica) petal and sepal length, stored in a 150x4 numpy.ndarray
#
# The rows being the samples and the columns being: Sepal Length, Sepal Width, Petal Length and Petal Width.

# %% [markdown]
# <img style="width: 500px;" src=https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png>

# %%
df
# Out:
#      sepal_len  sepal_wid  petal_len  petal_wid  f_class
# 0          5.1        3.5        1.4        0.2        0
# 1          4.9        3.0        1.4        0.2        0
# 2          4.7        3.2        1.3        0.2        0
# 3          4.6        3.1        1.5        0.2        0
# 4          5.0        3.6        1.4        0.2        0
# ..         ...        ...        ...        ...      ...
# 145        6.7        3.0        5.2        2.3        2
# 146        6.3        2.5        5.0        1.9        2
# 147        6.5        3.0        5.2        2.0        2
# 148        6.2        3.4        5.4        2.3        2
# 149        5.9        3.0        5.1        1.8        2
#
# [150 rows x 5 columns]

# %%
plt.hist(df.sepal_wid)
plt.show()

# %%
a, b, c = plt.hist(df.sepal_wid)

# %%
a
# Out:
# array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.])

# %%
b
# Out:
# array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ])

# %%
c
# Out:
# <BarContainer object of 10 artists>

# %%
h, bin_edges, c = plt.hist(df.sepal_wid)
bin_centers = (bin_edges[:-1]+bin_edges[1:])/2
plt.plot(bin_centers, h, color='red')

# %% [markdown]
# matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)

# %%
plt.hist(df.sepal_wid, bins=10, range=[2.5, 3.5])
plt.show()

# %%
plt.hist(df.sepal_wid, density=True)
plt.grid()
plt.show()

# %% [markdown]
# densitybool, default: False
#
# If True, draw and return a probability density: each bin will display the bin's raw count divided by the total number of counts and the bin width (density = counts / (sum(counts) * np.diff(bins))), so that the area under the histogram integrates to 1 (np.sum(density * np.diff(bins)) == 1).

# %%
plt.hist(df.sepal_wid, cumulative=True)
plt.grid()
plt.show()

# %%
plt.hist(df.sepal_wid, bins=15, alpha=0.5, label='sepal_wid')
plt.legend()
plt.grid()
plt.show()

# %%
plt.hist(df.sepal_wid, bins=15, histtype='step', lw=2, label='sepal_wid')
plt.legend()
plt.grid()
plt.show()

# %%
df.head()
# Out:
#    sepal_len  sepal_wid  petal_len  petal_wid  f_class
# 0        5.1        3.5        1.4        0.2        0
# 1        4.9        3.0        1.4        0.2        0
# 2        4.7        3.2        1.3        0.2        0
# 3        4.6        3.1        1.5        0.2        0
# 4        5.0        3.6        1.4        0.2        0

# %%
plt.hist(df.query('f_class==0').sepal_wid, range=[2, 5], bins=15, histtype='step', lw=2, label='class==0')
plt.legend()
plt.grid()
plt.xlabel('sepal_wid')
plt.show()

# %%
plt.hist([df.query(f'f_class=={i}').sepal_wid for i in [0, 1, 2]], range=[2, 5], bins=15, lw=2, stacked=True, label=['class 0', 'class 1', 'class 2'])
plt.legend()
plt.grid()
plt.xlabel('sepal_wid')
plt.show()

# %%
plt.hist(df.sepal_wid, range=[2, 5], bins=15, label='all classes')
plt.legend()
plt.grid()
plt.xlabel('sepal_wid')
plt.show()

# %%
for cl in [0, 1]:
    plt.hist(df.query(f'f_class=={cl}').sepal_wid, range=[2, 5], bins=15, ec="black", alpha=0.5, label=f'class=={cl}')
plt.legend()
plt.grid()
plt.xlabel('sepal_wid')
plt.show()

# %%
for feature in df.columns[:-1]:
    for cl in df.f_class.unique():
        plt.hist(df.query(f'f_class=={cl}')[feature], range=[df[feature].min(), df[feature].max()], bins=12, alpha=0.5, lw=2, label=f'class=={cl}')
    plt.legend()
    plt.grid()
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# ## Boxplot

# %% [markdown]
# A Box Plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum.
#
# In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.

# %% [markdown]
# <img style="width: 700px;" src=http://www.lac.inpe.br/~rafael.santos/Docs/CAP394/resources/interpret_boxplots.png>

# %% [markdown]
# <img style="width: 500px;" src=https://builtin.com/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/1_boxplots.jpg>

# %%
plt.boxplot([df.query(f'f_class=={i}').sepal_wid for i in [0, 1, 2]])
plt.xlabel('class')
plt.ylabel('sepal_wid')
# show plot
plt.show()

# %% [markdown]
# Each filled area extends to represent the entire data range, with optional lines at the mean, the median, the minimum, the maximum, and user-specified quantiles.

# %%
plt.violinplot([df.query(f'f_class=={i}').sepal_wid for i in [0, 1, 2]])
plt.xlabel('class')
plt.ylabel('sepal_wid')
# show plot
plt.show()

# %%
[[0.25, 0.75]]
# Out:
# [[0.25, 0.75]]

# %%
plt.violinplot([df.query(f'f_class=={i}').sepal_wid for i in [0, 1, 2]], showmedians=True, quantiles=[[0.25, 0.75],[0.25, 0.75],[0.25, 0.75]])
plt.xlabel('class')
plt.ylabel('sepal_wid')
# show plot
plt.show()

# %%
df.columns
# Out:
# Index(['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'f_class'], dtype='object')

# %%
for cl in df.f_class.unique():
    plt.scatter(df.query(f'f_class=={cl}')['sepal_len'], df.query(f'f_class=={cl}')['sepal_wid'], label=f'class=={cl}')
plt.legend()
plt.grid()
plt.xlabel('sepal_len')
plt.ylabel('sepal_wid')
plt.show()

# %% [markdown]
# # Seaborn
#
# an alternative to matplotlib
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# https://seaborn.pydata.org/

# %%
import seaborn as sns

# %%
sns.distplot(df.sepal_wid)
# Out:
# C:\Users\utente\AppData\Local\Temp\ipykernel_12536\2220659599.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.sepal_wid)
# <Axes: xlabel='sepal_wid', ylabel='Density'>

# %%
sns.jointplot(x='sepal_len',y='sepal_wid',data=df,size=5)

# %%
sns.color_palette("pastel")
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.jointplot(x='sepal_len',y='sepal_wid',data=df,size=5, hue='f_class', palette="pastel")

# %%
sns.boxplot(x='f_class',y='sepal_wid',data=df)
# Out:
# <Axes: xlabel='f_class', ylabel='sepal_wid'>

# %%
sns.pairplot(df, hue='f_class', size=2.5, palette="pastel")
# Out:
# C:\Users\utente\anaconda3\lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(7,4))
sns.heatmap(df[df.columns[:-1]].corr(),annot=True)
# Out:
# <Axes: >
