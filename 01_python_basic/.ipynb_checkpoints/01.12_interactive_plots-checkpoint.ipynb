# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib.widgets import Slider, Button


# The parametrized function to be plotted
def f(t, amplitude, frequency):
    return amplitude * np.sin(2 * np.pi * frequency * t)

t = np.linspace(0, 1, 1000)

# Define initial parameters
init_amplitude = 5
init_frequency = 3

# Create the figure and the line that we will manipulate
fig, ax = plt.subplots()
line, = ax.plot(t, f(t, init_amplitude, init_frequency), lw=2)
ax.set_xlabel('Time [s]')

# adjust the main plot to make room for the sliders
fig.subplots_adjust(left=0.25, bottom=0.25)

# Make a horizontal slider to control the frequency.
axfreq = fig.add_axes([0.25, 0.1, 0.65, 0.03])
freq_slider = Slider(
    ax=axfreq,
    label='Frequency [Hz]',
    valmin=0.1,
    valmax=30,
    valinit=init_frequency,
)

# Make a vertically oriented slider to control the amplitude
axamp = fig.add_axes([0.1, 0.25, 0.0225, 0.63])
amp_slider = Slider(
    ax=axamp,
    label="Amplitude",
    valmin=0,
    valmax=10,
    valinit=init_amplitude,
    orientation="vertical"
)


# The function to be called anytime a slider's value changes
def update(val):
    line.set_ydata(f(t, amp_slider.val, freq_slider.val))
    fig.canvas.draw_idle()


# register the update function with each slider
freq_slider.on_changed(update)
amp_slider.on_changed(update)

# Create a `matplotlib.widgets.Button` to reset the sliders to initial values.
resetax = fig.add_axes([0.8, 0.025, 0.1, 0.04])
button = Button(resetax, 'Reset', hovercolor='0.975')


def reset(event):
    freq_slider.reset()
    amp_slider.reset()
button.on_clicked(reset)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display

# funzione di potenza
def power_function(x, n):
    return x ** n

# creazione slider per l'esponente
n_slider = widgets.FloatSlider(
    value=2.0,
    min=1.0,
    max=5.0,
    step=0.1,
    description='Esponente:',
    continuous_update=True
)

# creazione figura e assi
fig, ax = plt.subplots()

# creazione del grafico vuoto
line, = ax.plot([], [])

# funzione per aggiornare il grafico in base al valore dello slider
def update_plot(n):
    x = np.linspace(-10, 10, 1000)
    y = power_function(x, n)
    line.set_data(x, y)
    ax.set_xlim(-10, 10)
    ax.set_ylim(-10, 10)
    fig.canvas.draw()

# collegamento della funzione di aggiornamento allo slider
widgets.interactive(update_plot, n=n_slider)

# mostrare lo slider e il grafico
display(n_slider)
plt.show()
# Out:
# FloatSlider(value=2.0, description='Esponente:', max=5.0, min=1.0)

# %%
# %matplotlib widget

fig = plt.figure()
plt.plot([1,2,3])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import mpld3
fig = plt.figure()
mpld3.display(fig)
ax = fig.gca()
ax.plot([1,2,3,4])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pip install --upgrade ipympl
# Out:
# Requirement already satisfied: ipympl in c:\users\utente\anaconda3\lib\site-packages (0.8.4)
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      ---------------------------------------- 0.0/511.6 kB ? eta -:--:--
#      ---- ---------------------------------- 61.4/511.6 kB 1.7 MB/s eta 0:00:01
#      --------- ---------------------------- 122.9/511.6 kB 1.4 MB/s eta 0:00:01
#      --------------- ---------------------- 204.8/511.6 kB 1.6 MB/s eta 0:00:01
#      -------------------- ----------------- 276.5/511.6 kB 1.5 MB/s eta 0:00:01
#      ------------------------- ------------ 337.9/511.6 kB 1.5 MB/s eta 0:00:01
#      ------------------------------- ------ 419.8/511.6 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------  501.8/511.6 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 511.6/511.6 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\utente\anaconda3\lib\site-packages (from ipympl) (3.4.3)
# Requirement already satisfied: pillow in c:\users\utente\anaconda3\lib\site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: numpy in c:\users\utente\anaconda3\lib\site-packages (from ipympl) (1.20.3)
# Requirement already satisfied: ipython<9 in c:\users\utente\anaconda3\lib\site-packages (from ipympl) (8.10.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\utente\anaconda3\lib\site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: ipython-genutils in c:\users\utente\anaconda3\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: traitlets<6 in c:\users\utente\anaconda3\lib\site-packages (from ipympl) (5.7.1)
# Requirement already satisfied: decorator in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: backcall in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: colorama in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: pickleshare in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (3.0.36)
# Requirement already satisfied: stack-data in c:\users\utente\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\utente\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\utente\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\utente\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\utente\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.19.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\utente\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\utente\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\utente\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\utente\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: pyzmq>=17 in c:\users\utente\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\utente\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\utente\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\utente\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.4.9)
# Requirement already satisfied: packaging in c:\users\utente\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.0)
# Requirement already satisfied: nest-asyncio in c:\users\utente\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.6)
# Requirement already satisfied: psutil in c:\users\utente\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\utente\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\utente\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: jupyter-core in c:\users\utente\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (5.3.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\utente\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (3.2.0)
# Requirement already satisfied: wcwidth in c:\users\utente\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\utente\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\utente\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.5)
# Requirement already satisfied: executing in c:\users\utente\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\utente\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\utente\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\utente\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\utente\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: setuptools in c:\users\utente\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (65.6.3)
# Requirement already satisfied: entrypoints in c:\users\utente\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: pywin32>=300 in c:\users\utente\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\utente\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.5.2)
# Requirement already satisfied: jinja2 in c:\users\utente\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\utente\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: nbconvert in c:\users\utente\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\utente\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\utente\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\utente\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\utente\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\utente\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\utente\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\utente\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: testpath in c:\users\utente\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\utente\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: bleach in c:\users\utente\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\utente\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\utente\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\utente\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: async-generator in c:\users\utente\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.10)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\utente\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: webencodings in c:\users\utente\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\utente\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)
# Installing collected packages: ipympl
#   Attempting uninstall: ipympl
#     Found existing installation: ipympl 0.8.4
#     Uninstalling ipympl-0.8.4:
#       Successfully uninstalled ipympl-0.8.4
# Successfully installed ipympl-0.9.3
# Note: you may need to restart the kernel to use updated packages.
