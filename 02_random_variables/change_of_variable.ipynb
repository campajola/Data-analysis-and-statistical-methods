# %%
import matplotlib.pyplot as plt
import numpy as np

import random
#help(random)

# %% [markdown]
# ### uniform distribution in [0,1[

# %% [raw]
# help(np.random.rand)

# %%
np.random.rand(3)
# Out:
# array([0.96120211, 0.22729211, 0.90332284])

# %%
N = 100000
plt.hist(np.random.rand(N), bins=100, histtype='step', density=True)
plt.plot(x, x/x, '--', label='f(x) = 1')

plt.grid()

plt.legend()

plt.xlabel('x')

plt.show()
# Out:
# /tmp/ipykernel_2142/3975973941.py:3: RuntimeWarning: invalid value encountered in divide
#   plt.plot(x, x/x, '--', label='f(x) = 1')

# %%
N = 100000
hitst_range=[0, 1]
nbins=50
plt.hist(np.random.rand(N)**2, bins=nbins, range = [0, 1], histtype='step', density=True)

x=np.linspace(hitst_range[0], hitst_range[1], nbins, endpoint=False)
plt.plot(x, 1/(2*np.sqrt(x)), '--', label='g(y) = 1/(2*sqrt(y))')

plt.legend()

plt.xlabel('y')
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_2142/331822857.py:7: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(x, 1/(2*np.sqrt(x)), '--', label='g(y) = 1/(2*sqrt(y))')
