# %% [markdown]
# # Random Walk

# %% [markdown]
# From ```Wikipedia```
#
#
# In mathematics, a random walk is a random process that describes a path that consists of a succession of random steps on some mathematical space.
#
# An elementary example of a random walk is the random walk on the integer number line Z  which starts at 0, and at each step moves +1 or −1 with equal probability.
#
# Other examples include the path traced by a molecule as it travels in a liquid or a gas (see Brownian motion), the search path of a foraging animal, or the price of a fluctuating stock and the financial status of a gambler.

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Set up parameters
num_steps = 100  # Number of steps in the random walk
step_size = 1  # Size of each step
start_pos = 0  # Starting position of the random walk

# Create an array to store the positions of the random walk
positions = np.zeros(num_steps)

# Simulate the random walk
for i in range(num_steps):
    positions[i] = start_pos
    start_pos += np.random.choice([-step_size, step_size])

# Set up the plot
fig, ax = plt.subplots()
ax.set_xlim(0, num_steps)
ax.set_ylim(np.min(positions), np.max(positions))
line, = ax.plot([], [])

# Define the animation function
def update(i):
    x = np.arange(i)
    y = positions[:i]
    line.set_data(x, y)
    return line,

# Create the animation
ani = animation.FuncAnimation(fig, update, frames=num_steps, interval=50)

plt.close()
# Display the animation
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4411cea04a0848a1975e084f46aeea2a">
#   <div class="anim-controls">
#     <input id="_anim_slider4411cea04a0848a1975e084f46aeea2a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4411cea04a0848a1975e084f46aeea2a.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim4411cea04a0848a1975e084f46aeea2a.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim4411cea04a0848a1975e084f46aeea2a.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim4411cea04a0848a1975e084f46aeea2a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim4411cea04a0848a1975e084f46aeea2a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim4411cea04a0848a1975e084f46aeea2a.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim4411cea04a0848a1975e084f46aeea2a.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim4411cea04a0848a1975e084f46aeea2a.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim4411cea04a0848a1975e084f46aeea2a.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim4411cea04a0848a1975e084f46aeea2a.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select4411cea04a0848a1975e084f46aeea2a"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4411cea04a0848a1975e084f46aeea2a"
#              >
#       <label for="_anim_radio1_4411cea04a0848a1975e084f46aeea2a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4411cea04a0848a1975e084f46aeea2a"
#              checked>
#       <label for="_anim_radio2_4411cea04a0848a1975e084f46aeea2a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4411cea04a0848a1975e084f46aeea2a"
#              >
#       <label for="_anim_radio3_4411cea04a0848a1975e084f46aeea2a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4411cea04a0848a1975e084f46aeea2a";
#     var slider_id = "_anim_slider4411cea04a0848a1975e084f46aeea2a";
#     var loop_select_id = "_anim_loop_select4411cea04a0848a1975e084f46aeea2a";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy88F64QAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAcKElE

# %%
n = 1000 #number of steps

x_0 = 0 #starting point
step=1
x_values = [x_0] #list to store positions
N = [0] #list to store step number

for i in range(n): #'walking' over n steps
    t = random.uniform(0, 1)
    if t>0.5: step_x = step
    else: step_x = -step
    x_values.append(x_values[-1] + step_x)
    N.append(i)

plt.plot(N, x_values, '-')
plt.axhline(y=0, color='red')
plt.scatter(0, x_0, color='red')
plt.title("Random Walk")
plt.xlabel("n", size=14)
plt.ylabel("x", size=14)
plt.grid()
plt.show()

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

n = 1000
x_0 = 0
step = 1
NEXP = 10

for rn in range(NEXP):
    x_values = [x_0]
    N = [0]
    for i in range(n):
        t = random.uniform(0, 1)
        if t>0.5: step_x = step
        else: step_x = -step
        x_values.append(x_values[-1] + step_x)
        N.append(i)
    plt.plot(N, x_values, '-')
    
plt.title("Random Walk")
plt.xlabel("n", size=14)
plt.ylabel("x", size=14)
plt.grid()
plt.show()

# %%
res=[]
n = 100
x_0 = 0
step = 1

    
NEXP = 10000

for m in range(NEXP):
    x_values = [x_0]
    N = [0]
    for i in range(n):
        t = random.uniform(0, 1)
        if t>0.5: step_x = step
        else: step_x = -step
        x_values.append(x_values[-1] + step_x)
        N.append(i)
    res+=[x_values[-1]]

plt.hist(res, bins=11, histtype='step')
plt.annotate(f'mean = {np.mean(res):.3f}', xy=(.05,.9), xycoords='axes fraction', size=12)
plt.annotate(f'std. dev. = {np.std(res):.3f}', xy=(.05,.80), xycoords='axes fraction', size=12)
plt.title(f'distance after {n} steps')
plt.xlabel('distance')
plt.show()

# %%
n = 100
x_0 = 0
step = 1
NEXP = 10000

NSTEP=[1, 10, 100, 200, 400, 600]
STD=[]
for n in NSTEP:
    res=[]
    for m in range(NEXP):
        x_values = [x_0]
        N = [0]
        for i in range(n):
            t = random.uniform(0, 1)
            if t>0.5: step_x = step
            else: step_x = -step
            x_values.append(x_values[-1] + step_x)
            N.append(i)
        res+=[x_values[-1]]
    STD+=[np.std(res)]

# %%
plt.scatter(NSTEP, STD)
plt.xlabel('max step', size=14)
plt.ylabel('std. dev. of distance', size=14)
x=np.arange(0, 800, 10)
plt.plot(x, np.sqrt(x), '--', color='orange')

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

n = 1000
x_0 = 0
step = 1
NEXP = 100

for rn in range(NEXP):
    x_values = [x_0]
    N = [0]
    for i in range(n):
        t = random.uniform(0, 1)
        if t>0.5: step_x = step
        else: step_x = -step
        x_values.append(x_values[-1] + step_x)
        N.append(i)
    plt.plot(N, x_values, '-', color='C0', lw=0.1)
    
x=np.arange(0, 1000, 10)
plt.plot(x, np.sqrt(x)+x_0, '--', lw=2, color='red')
plt.plot(x, -np.sqrt(x)+x_0, '--', lw=2, color='red')
plt.title("Random Walk")
plt.xlabel("n", size=14)
plt.ylabel("x", size=14)
plt.grid()
plt.show()

# %%
import random
import matplotlib.pyplot as plt

# Definisci la lunghezza del random walk
n = 10000

# Definisci i valori iniziali per la posizione x e y
x_0 = 0
y_0 = 0

# Crea le liste per memorizzare i valori x e y della posizione
x_values = [x_0]
y_values = [y_0]

# Genera il random walk
for i in range(n):
    # Definisci i passi casuali per la posizione x e y
    step_x = random.uniform(-1, 1)
    step_y = random.uniform(-1, 1)

    # Aggiungi i passi alla posizione attuale x e y
    x_values.append(x_values[-1] + step_x)
    y_values.append(y_values[-1] + step_y)

# Crea il grafico del random walk
plt.plot(x_values, y_values)
plt.title("Random Walk in 2D")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
